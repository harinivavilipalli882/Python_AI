# %%
print("Hello world")

# %% [markdown]
# #### Case senitive

# %%
name = "Harini"
Name = "Harini"
name == Name
# Out:
# True

# %%
name = "Harini"
Name = "harini"
name == Name
# Out:
# False

# %% [markdown]
# #### Indentation

# %%
age = 23

if age < 13:
    print("You are a child.")
elif age < 20:
    print("You are a teenager.")
else:
    print("You are an adult.")
# Out:
# You are an adult.

# %% [markdown]
# #### Use back slash \ for multiple lines of code

# %%
1+2+3+\
4+5
# Out:
# 15

# %% [markdown]
# #### Use semicolon to separate multiple statements/declarations in one line

# %%
Nmae = "Harini" ; age = 23

# %% [markdown]
# #### Comments

# %%
#Single line comments
# Multiple line 

"""
This is a comment
written in
more than just one line
"""
# Out:
# '\nThis is a comment\nwritten in\nmore than just one line\n'
