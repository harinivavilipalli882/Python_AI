# %% [markdown]
# ### Variables

# %%
age = 23
Name = 'Harini'
Height = 5.3
is_True = True

# %%
age
# Out:
# 23

# %%
Name
# Out:
# 'Harini'

# %%
Height
# Out:
# 5.3

# %%
is_True
# Out:
# True

# %%
print("age is" ,age)
print("Name is", Name)
# Out:
# age is 23
# Name is Harini

# %% [markdown]
# #### Naming Convention
# ##### Must start with underscore/letter, can contain letter numbers & undescores. Example : _name  , name1
# ##### Case sensitive

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
age = str(age)  #type cast int to str

print(age)
print(type(age)) #A string can be converted to int but viceversa will give an error.
# Out:
# 23
# <class 'str'>

# %% [markdown]
# #### Input() function
# ##### Input function only takes the input format and unless we are not going to explicitly take the input in integer or any other format.

# %%
Age = input("Enter your age:")
print(type(Age))
# Out:
# <class 'str'>

# %%
Age = int(input("Enter your age :"))
print(type(Age))
# Out:
# <class 'int'>

# %%
Value = bool(input("Enter a value:"))
print(type(Value))
# Out:
# <class 'bool'>

# %% [markdown]
# #### Building a simple calculator

# %%
Value_1 = int(input("Enter your first number:"))
Value_2 = int(input("Enter your Second number:"))
print("Addition:" , Value_1 + Value_2)
print("Subtraction:" , Value_1 - Value_2)
print("Multiplication:" , Value_1 * Value_2)
print("Division:" , Value_1 / Value_2)
# Out:
# Addition: 50
# Subtraction: 10
# Multiplication: 600
# Division: 1.5
