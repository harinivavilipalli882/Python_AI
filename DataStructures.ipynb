# %% [markdown]
# #### DataStructure

# %% [markdown]
# ##### Data structures in python are being used for storing the data in a structures format . so that we can access the data and along with that we can perform all of the operation swith these data structures that we can perform in the caase of databases as well like CRUD(Create, Read, Update, Delete) operations.
#
# ##### The different type of data structures differs on this basis that in which specific format we want to store our data.

# %% [markdown]
# ##### Tpes of Data Structure in python:
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary
