# %% [markdown]
# #### List
# #####  List are one of teh type of data structure which are used for storing your data in a structured format where you can store data of any data type and that is one of the data structure so we can have access to the data aswell that we are going to store into the list and we can apply crud operations as well (create, read, update, delete).
# ##### Lists are ordered and mutable Data structure.

# %%
a = list()
type(a)
# Out:
# list

# %%
Lists = [1,2,3,4,5]
print(Lists)
# Out:
# [1, 2, 3, 4, 5]

# %%
lists = ["Harini",8,2.5,True]
print(lists)
# Out:
# ['Harini', 8, 2.5, True]

# %%
'''By using data dtructures, we can apply the crud operations like inserting the data,deleting , updating and reading the data.'''

lists = ["Harini",1,2,3,4,5,6,2.5,True]
print(lists)
# Out:
# ['Harini', 1, 2, 3, 4, 5, 6, 2.5, True]

# %% [markdown]
# #### List indexing

# %%
# By using proper indexing value, we can retreive the data from our lists.
# Indexing in List --> 0 to (Length-1)
print(lists[0])
# Out:
# Harini

# %% [markdown]
# #### Len() function
# ##### Length of a data structure is going to be the total items we are having in that data structure.

# %%
lists = ["Harini",1,2,3,4,5,6,2.5,True]
print(len(lists))
# Out:
# 9

# %%
print(lists)
# Out:
# ['Harini', 1, 2, 3, 4, 5, 6, 2.5, True]
