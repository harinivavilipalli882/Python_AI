# %% [markdown]
# #### Data types are classification of the data that tells the compiler or the interpreter that what kind of values we can store into a variable and how much memory will be consumed to store data and the operations it can perform

# %%
age = input("Enter age:")

# %%
age
# Out:
# '20'

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age2 = 23
print(age+age2)  #This opertaion will give us an eror.Because age will be in str format.Too avoid the error, take the age as int(input("Enter age:"))

# %%
age = int(input("Enter age:"))
print(type(age))
age2 = 23
print(age+age2)
# Out:
# <class 'int'>
# 43

# %% [markdown]
# #### Different types of Datatypes
# 1. Int
# 2. str
# 3. bool
# 4. float

# %%
a = 23
type(a)
# Out:
# int

# %%
b = "Harini"
type(b)
# Out:
# str

# %%
c = 23.5
type(c)
# Out:
# float

# %%
is_true = True
type(is_true)
# Out:
# bool

# %%
a = 23
b = 25
a == b
# Out:
# False
