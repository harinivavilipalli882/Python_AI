# %% [markdown]
# #### Operators

# %% [markdown]
# #### Operators help in applying operations on the given operands

# %% [markdown]
# ### Types of operators
#
# 1. Arithmetic operators
# Addition (+)
# Subtraction (-)
# Multiplication or product (*)
# Division (/) - will result the quotient
# Modulus (%) - will result the Remainder
# Floor (//)
# Exponent (a**b)
#
# 2. Comparision operators
# Greater than(>)
# Less than(<)
# Greater than or equal to(>=)
# Less than or equal to(<=)
# Equality check (==)
# not eaual to(!=)
#
# 3. Logical operators
# AND --> If both conditions are true
# OR --> If any of the operation/condition is true.
# NOT --> negation/inverse of the given operation

# %%
# Arithmetic operators
a = 25
b = 8
print("Addition :",a+b) #Addition
print("Subtraction :",a-b) #Subtraction
print("Multiplication :",a*b) #Multiplication
print("Division :",a/b) #Division
print("Modulus :",a%b) #Modulus 
print("Floor :",a//b) #Floor
print("Exponent :",a**b) #Exponent
# Out:
# Addition : 33
# Subtraction : 17
# Multiplication : 200
# Division : 3.125
# Modulus : 1
# Floor : 3
# Exponent : 152587890625

# %%
# Comparision operators       
a = 25
b = 8
print("a and b are equal :",a == b) # Equality check (==)
print("a is not equal to b :",a != b) # not eaual to(!=)
print("a is greater than b :",a > b)# Greater than(>)       
print("a is less than b :",a < b)# Less than(<)       
print("a is greater than or equal to b :",a >= b)# Greater than or equal to(>=)       
print("a is less than or equal to b :",a <= b)# Less than or equal to(<=)
# Out:
# a and b are equal : False
# a is not equal to b : True
# a is greater than b : True
# a is less than b : False
# a is greater than or equal to b : True
# a is less than or equal to b : False

# %%
#Logical Operators
a = 25
b = 8
c = True

print(a>b and b<a)  #AND 
print(a>b or a<b)  #OR        
print(not c)#NOT
# Out:
# True
# True
# False

# %% [markdown]
# #### Claculator based on given numbers and the operation

# %%
a = int(input("Enter the value of a:"))
b = int(input("Enter the value of b:"))
operation = input("Enter the operation to be prformed for a and b:")

if operation == "+":
    print("Addition of a and b is:", a+b)
if operation == "-":
    print("Subtraction of a and b is:", a-b)
if operation == "*":
    print("Multiplication of a and b is:", a*b)
if operation == "/":
    print("Division of a and b is:", a/b)
# Out:
# Addition of a and b is: 5
